# %%
from src.eda_utils import faceted_histogram_plot, salary_per_category_table, PlotStats
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/interim/salaries_train_all.csv')
avg_salary_per_jobtype = salary_per_category_table('jobType', df)
salary_stats = PlotStats(df, 'salary')

# %%
faceted_histogram_plot(df, 'jobType',
                       grid_kwargs = {'col_wrap': 4, 'col_order': avg_salary_per_jobtype.jobType},
                       plot_kwargs = {'binwidth': 5, 'plot_stats': salary_stats})
